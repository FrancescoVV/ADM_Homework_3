# %%
from bs4 import BeautifulSoup
import requests
import time
import os

# %%
for i in range(1,301):
    for j in range(1,101):
        path="F:\ADM3\ADM3\\"+str(i)+"\\"+str(j)+".html"
        os.path.getsize(path)
    if i%25==0:
        print (i)
# Out:
# 25
# 50
# 75
# 100
# 125
# 150
# 175
# 200
# 225
# 250
# 275
# 300

# %%
for i in range(1,301):
    file= "F:\ADM3\ADM3\\" +str(i)+"\\"+"links.txt"
    f=open(file,encoding="utf-8")
    lines=f.readlines()
    j=1
    for url in lines:
        
        name="F:\ADM3\ADM3\\"+str(i)+"\\"+str(j)+".html"
        if os.path.getsize(name)<100000:
            temp=os.path.getsize(name)
            os.remove(name)
            print("removed file", name,"was of size",temp)
        j+=1
    print("Pagina "+str(i)+" finita")
# Out:
# Pagina 1 finita
# Pagina 2 finita
# Pagina 3 finita
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-aa8c3198f43a> in <module>
#       7
#       8         name="F:\ADM3\ADM3\\"+str(i)+"\\"+str(j)+".html"
# ----> 9         if os.path.getsize(name)<100000:
#      10             temp=os.path.getsize(name)
#      11             os.remove(name)
#
# D:\Anaconda\lib\genericpath.py in getsize(filename)
#      48 def getsize(filename):
#      49     """Return the size of a file, reported by os.stat()."""
# ---> 50     return os.stat(filename).st_size
#      51
#      52
#
# FileNotFoundError: [WinError 2] Impossibile trovare il file specificato: 'F:\\ADM3\\ADM3\\4\\12.html'

# %%
s=requests.Session()
for i in range(1,301):
    file= "G:\ADM3\\" +str(i)+"\\"+"links.txt"
    f=open(file,encoding="utf-8")
    lines=f.readlines()
    j=1
    for url in lines:
        
        name="G:\ADM3\ADM3\\"+str(i)+"\\"+str(j)+".html"
        f=open(name,"r")
        f.close()
        j+=1
        print(name)
    print("Pagina "+str(i)+" finita")
# Out:
# F:\ADM3\ADM3\1\1.html
# F:\ADM3\ADM3\1\2.html
# F:\ADM3\ADM3\1\3.html
# F:\ADM3\ADM3\1\4.html
# F:\ADM3\ADM3\1\5.html
# F:\ADM3\ADM3\1\6.html
# F:\ADM3\ADM3\1\7.html
# F:\ADM3\ADM3\1\8.html
# F:\ADM3\ADM3\1\9.html
# F:\ADM3\ADM3\1\10.html
# F:\ADM3\ADM3\1\11.html
# F:\ADM3\ADM3\1\12.html
# F:\ADM3\ADM3\1\13.html
# F:\ADM3\ADM3\1\14.html
# F:\ADM3\ADM3\1\15.html
# F:\ADM3\ADM3\1\16.html
# F:\ADM3\ADM3\1\17.html
# F:\ADM3\ADM3\1\18.html
# F:\ADM3\ADM3\1\19.html
# F:\ADM3\ADM3\1\20.html
# F:\ADM3\ADM3\1\21.html
# F:\ADM3\ADM3\1\22.html
# F:\ADM3\ADM3\1\23.html
# F:\ADM3\ADM3\1\24.html
# F:\ADM3\ADM3\1\25.html
# F:\ADM3\ADM3\1\26.html
# F:\ADM3\ADM3\1\27.html
# F:\ADM3\ADM3\1\28.html
# F:\ADM3\ADM3\1\29.html
# F:\ADM3\ADM3\1\30.html
# F:\ADM3\ADM3\1\31.html
# F:\ADM3\ADM3\1\32.html
# F:\ADM3\ADM3\1\33.html
# F:\ADM3\ADM3\1\34.html
# F:\ADM3\ADM3\1\35.html
# F:\ADM3\ADM3\1\36.html
# F:\ADM3\ADM3\1\37.html
# F:\ADM3\ADM3\1\38.html
# F:\ADM3\ADM3\1\39.html
# F:\ADM3\ADM3\1\40.html
# ...
