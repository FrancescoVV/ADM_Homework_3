# %%
from bs4 import BeautifulSoup
import requests
import time
import os

# %%
#This loop downloads the 300 pages.
for i in range(1,301):
    link="https://www.goodreads.com/list/show/1.Best_Books_Ever?page="+str(i)
    cnt = requests.get(link)
    soup = BeautifulSoup(cnt.content, features="lxml")
    name="G:\ADM3\\"+str(i)+"\\"+"page"+str(i)+".html"
    print(name)
    f = open(name, "w",encoding="utf-8")
    f.write(soup.prettify())
    f.close()
    print("Pagina "+str(i)+" finita")
# Out:
# G:\ADM3\1\page1.html
# Pagina 1 finita
# G:\ADM3\2\page2.html
# Pagina 2 finita
# G:\ADM3\3\page3.html
# Pagina 3 finita
# G:\ADM3\4\page4.html
# Pagina 4 finita
# G:\ADM3\5\page5.html
# Pagina 5 finita
# G:\ADM3\6\page6.html
# Pagina 6 finita
# G:\ADM3\7\page7.html
# Pagina 7 finita
# G:\ADM3\8\page8.html
# Pagina 8 finita
# G:\ADM3\9\page9.html
# Pagina 9 finita
# G:\ADM3\10\page10.html
# Pagina 10 finita
# G:\ADM3\11\page11.html
# Pagina 11 finita
# G:\ADM3\12\page12.html
# Pagina 12 finita
# G:\ADM3\13\page13.html
# Pagina 13 finita
# G:\ADM3\14\page14.html
# Pagina 14 finita
# G:\ADM3\15\page15.html
# Pagina 15 finita
# G:\ADM3\16\page16.html
# Pagina 16 finita
# G:\ADM3\17\page17.html
# Pagina 17 finita
# G:\ADM3\18\page18.html
# Pagina 18 finita
# G:\ADM3\19\page19.html
# Pagina 19 finita
# G:\ADM3\20\page20.html
# Pagina 20 finita
# G:\ADM3\21\page21.html
# Pagina 21 finita
# G:\ADM3\22\page22.html
# Pagina 22 finita
# G:\ADM3\23\page23.html
# Pagina 23 finita
# G:\ADM3\24\page24.html
# Pagina 24 finita
# G:\ADM3\25\page25.html
# Pagina 25 finita
# G:\ADM3\26\page26.html
# Pagina 26 finita
# G:\ADM3\27\page27.html
# Pagina 27 finita
# G:\ADM3\28\page28.html
# Pagina 28 finita
# G:\ADM3\29\page29.html
# Pagina 29 finita
# G:\ADM3\30\page30.html
# Pagina 30 finita
# G:\ADM3\31\page31.html
# Pagina 31 finita
# G:\ADM3\32\page32.html
# Pagina 32 finita
# G:\ADM3\33\page33.html
# Pagina 33 finita
# G:\ADM3\34\page34.html
# Pagina 34 finita
# G:\ADM3\35\page35.html
# Pagina 35 finita
# G:\ADM3\36\page36.html
# Pagina 36 finita
# G:\ADM3\37\page37.html
# Pagina 37 finita
# G:\ADM3\38\page38.html
# Pagina 38 finita
# G:\ADM3\39\page39.html
# Pagina 39 finita
# G:\ADM3\40\page40.html
# Pagina 40 finita
# G:\ADM3\41\page41.html
# Pagina 41 finita
# G:\ADM3\42\page42.html
# Pagina 42 finita
# G:\ADM3\43\page43.html
# Pagina 43 finita
# G:\ADM3\44\page44.html
# Pagina 44 finita
# G:\ADM3\45\page45.html
# Pagina 45 finita
# G:\ADM3\46\page46.html
# Pagina 46 finita
# G:\ADM3\47\page47.html
# Pagina 47 finita
# G:\ADM3\48\page48.html
# Pagina 48 finita
# G:\ADM3\49\page49.html
# Pagina 49 finita
# G:\ADM3\50\page50.html
# Pagina 50 finita
# G:\ADM3\51\page51.html
# Pagina 51 finita
# G:\ADM3\52\page52.html
# Pagina 52 finita
# G:\ADM3\53\page53.html
# Pagina 53 finita
# G:\ADM3\54\page54.html
# Pagina 54 finita
